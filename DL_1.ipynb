# %% [markdown]
# <a href="https://colab.research.google.com/github/2018jangminjun/python/blob/main/DL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sklearn 표준화 연습용이 아닌 진짜임
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive

Data_set = pd.read_csv('/content/caffeine.csv')
X = Data_set.iloc[:,1:4]
Y = Data_set.iloc[:,4]

#Data_set == caffeine_df

scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_df_scaled = pd.DataFrame(data=X_scaled)
X = X_df_scaled
Y = pd.get_dummies(Y)

model = Sequential()
model.add(Dense(30,input_dim=3,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(6,activation='softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(X,Y,epochs=200,batch_size=3)

plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()

plt.plot(history.history['accuracy'])
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 30)                120
#
#  dense_10 (Dense)            (None, 10)                310
#
#  dense_11 (Dense)            (None, 6)                 66
#
# ...
# Total params: 496
# Trainable params: 496
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 204/204 [==============================] - 1s 3ms/step - loss: 1.8225 - accuracy: 0.1787
# Epoch 2/200
# 204/204 [==============================] - 1s 2ms/step - loss: 1.5850 - accuracy: 0.3213
# Epoch 3/200
# 204/204 [==============================] - 1s 4ms/step - loss: 1.5424 - accuracy: 0.3754
# Epoch 4/200
# 204/204 [==============================] - 1s 4ms/step - loss: 1.5260 - accuracy: 0.3590
# Epoch 5/200
# ...
