# %% [markdown]
# <a href="https://colab.research.google.com/github/2018jangminjun/python/blob/main/Gradient_descent%2C_matplotlib%2C_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,2,0.1)
y = x**2+np.sin(3*x+7)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
#import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + (1/5)* b**2 +7* np.sin(a*b)

def grad_f(a,b): # gradient
  h=1e-3
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-3, -3], iters =40, alpha = 0.05)

# f(x,y) = x^2 + y^2 함수의 그래프 그리기
fig = plt.figure(figsize=(30, 30))
ax = fig.gca(projection='3d')
#plt.hold(True)
a = np.arange(-3, 3, 0.25)
b = np.arange(-3, 3, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [13.6848294  23.36448876 21.14706499 14.97799798 14.50968648  5.346404
#  21.09200522 22.07926703  7.76340609  8.69226055  5.96808985 -5.19101768
#  -5.09601409 -4.85181379 -4.5554683  -4.01238145 -4.20022661 -4.00262499
#  -4.80183633 -4.918662   -5.30630699 -5.40669232 -5.52482193 -5.56734432
#  -5.59892542 -5.61310246 -5.62202029 -5.62714047 -5.63072214 -5.63341488
#  -5.63563668 -5.63754374 -5.63921936 -5.64070366 -5.64202311 -5.64319657
#  -5.64424002 -5.64516721 -5.64599053 -5.64672107 -5.64736882]

# %%
import os
import pandas as pd
import seaborn as sns
from google.colab import drive

df = pd.read_csv('/content/caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":300}) 
sns.set(rc={"figure.figsize":(3,3)})

sns.scatterplot(x="Caffeine (mg)", y ="Volume (ml)", data=df, hue ='type')

# %%
import os
import pandas as pd
import seaborn as sns
from google.colab import drive

df = pd.read_csv('/content/caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":300}) 
sns.set(rc={"figure.figsize":(3,3)})
sns.scatterplot(x="Caffeine (mg)", y ="Calories", data=df, hue ='type')
